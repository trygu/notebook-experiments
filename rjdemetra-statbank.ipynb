# %% [markdown]
# ## Demo av RJDemetra + PxWebApiData

# %%
library(PxWebApiData)
library(RJDemetra)

# %% [markdown]
# Henter ujustert volumindeks fra NACE 47.1 - Butikkhandel med bredt vareutvalg, fra Statistikkbanken (https://www.ssb.no/statbank/table/07129/). Alle måneder fra 2000 til i dag.

# %%
innData <- ApiData(7129, NACE = "47.1", ContentsCode = "VolumUjustert", Tid = TRUE)
ujustert <- ts(innData$dataset$value, freq = 12, start = c(2000, 1))

# %%
x13_model <- x13(ujustert)

# %%
plot(x13_model, type_chart = c("sa-trend", "cal-seas-irr"))
plot(x13_model$decomposition)
plot(x13_model$regarima)
# Out:
# Plot with title “Y, Sa, trend”
# Plot with title “Cal., sea., irr.”
# plot without title
# plot without title
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# plot without title
